# %% [markdown]
# #Structured output fra prompts

# %% [markdown]
# ###Install OpenAI components

# %%
pip install openai

# %%
pip install python-dotenv

# %% [markdown]
# ###Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from dotenv import load_dotenv

# %% [markdown]
# ###Load .env file

# %%
load_dotenv('drive/My Drive/Colab Notebooks/.env')

# %% [markdown]
# ###Initialize Open AI client

# %%
from openai import OpenAI as openai

# %%
import os
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.api_key

# %%
client = openai()

# %% [markdown]
# ###ChatGPT routine

# %%
def chat_completion(prompt, model="gpt-4", temperature=0):
    res = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=temperature,
    )
    result = res.choices[0].message.content
    print(result)
    return result

# %% [markdown]
# ###Prompt for structured JSON chat response

# %%
prompt = """
Give a JSON output with 13 names of animals and number of legs and skin coloer. The output must be accepted
by json.loads.
"""

# %% [markdown]
# ###Generate chat completion

# %%
result = chat_completion(prompt, model='gpt-4')
# Out:
# [
#     {
#         "name": "Dog",
#         "legs": 4,
#         "skin_color": "varies"
#     },
#     {
#         "name": "Cat",
#         "legs": 4,
#         "skin_color": "varies"
#     },
#     {
#         "name": "Elephant",
#         "legs": 4,
#         "skin_color": "grey"
#     },
#     {
#         "name": "Spider",
#         "legs": 8,
#         "skin_color": "varies"
#     },
#     {
#         "name": "Frog",
#         "legs": 4,
#         "skin_color": "green"
#     },
#     {
#         "name": "Chicken",
#         "legs": 2,
#         "skin_color": "white"
#     },
#     {
#         "name": "Horse",
#         "legs": 4,
#         "skin_color": "varies"
#     },
#     {
#         "name": "Cow",
#         "legs": 4,
#         "skin_color": "varies"
#     },
#     {
#         "name": "Pig",
#         "legs": 4,
#         "skin_color": "pink"
#     },
#     {
#         "name": "Duck",
#         "legs": 2,
#         "skin_color": "varies"
#     },
#     {
#         "name": "Lion",
#         "legs": 4,
#         "skin_color": "yellow"
#     },
#     {
#         "name": "Tiger",
#         "legs": 4,
#         "skin_color": "orange"
#     },
#     {
#         "name": "Bear",
#         "legs": 4,
#         "skin_color": "brown"
#     }
# ]

# %% [markdown]
# ###Load response into JSON

# %%
import json

loadedJSON=json.loads(result)

# %%
animals=loadedJSON["animals"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-b1bcaee7c94a> in <cell line: 1>()
# ----> 1 animals=loadedJSON["animals"]
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# ###Displaying data for first animal

# %%
animals[0]

# %% [markdown]
# ###Displaying data in a formattet way

# %%
for a in animals:
  print("Details on " + a["name"]+":")
  #print("    Continent: " + a["continent"])
  print("    Legs:      " + str(a["legs"]))

# %% [markdown]
# #Exercises

# %% [markdown]
# 1.   Try to add more animal attributes (e.g. continent, nutrition, ...) to the prompt.
# 2. Try vary on the number for animals.
# 3. Does it always work?
# 4. Briefly, describe you how would incorporate a feature as the one you developed above into an app. Not technically, but conceptually taking into account that the chat response not always may have an apprapiate structure for formatting.

# %% [markdown]
# 3.Does it always work?
# nej den har fjernet den ene animals gruppe så den fejler. disse fejl kan komme frem så snart nogle er inde og ændre i parimenterne for programmet og den algoritme dem den bruger.
# 4.Briefly, describe you how would incorporate a feature as the one you developed above into an app. Not technically, but conceptually taking into account that the chat response not always may have an apprapiate structure for formatting?
# Det er en vigtigt at sikre sig at have test cases og planlægge sikkerheds punkter i løbet af sin udvikling for at tjekke udput.
